# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# !pip install -q bert-extractive-summarizer
# !pip install -q spacy==2.1.3
# !pip install -q transformers==2.2.2
# !pip install -q neuralcoref
# !pip install torch==1.6.0+cpu torchvision==0.7.0+cpu -f https://download.pytorch.org/whl/torch_stable.html
# !pip install bert-extractive-summarizer==0.5.0
import torch
from summarizer import Summarizer
import pandas as pd
# Out:
# Mounted at /content/gdrive
#      |████████████████████████████████| 3.8 MB 7.1 MB/s
#      |████████████████████████████████| 596 kB 63.5 MB/s
#      |████████████████████████████████| 67 kB 5.4 MB/s
#      |████████████████████████████████| 895 kB 46.3 MB/s
#      |████████████████████████████████| 6.5 MB 44.6 MB/s
#      |████████████████████████████████| 27.7 MB 80.3 MB/s
#      |████████████████████████████████| 3.2 MB 39.9 MB/s
#      |████████████████████████████████| 82 kB 349 kB/s
#      |████████████████████████████████| 2.1 MB 47.7 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbclient 0.5.13 requires jupyter-client>=6.1.5, but you have jupyter-client 5.3.5 which is incompatible.
# en-core-web-sm 2.2.5 requires spacy>=2.2.2, but you have spacy 2.1.3 which is incompatible.
# ...

# %%
# load in WikiHow dataset 
df_1024 = pd.read_csv('gdrive/MyDrive/SNLP_Coursework/WikiHow_sample_in1024.csv')
n = len(df_1024) / 2
print(n)
# Out:
# 8942.0

# %%
# df_1024['train_length'] = 'empty'
# df_1024['summary'] = 'empty'
# df_1024['summary_length'] = 'empty'
# df_1024.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0  \nShop around for the best rate.,\nRequest quo...
# 1           1  \nBecome familiar with your resources.,\nKnow ...
# 2           2  \nKnow local maps.,\nKnow the world map.,\nAcc...
# 3           3  \nRemove your shoes and socks, if necessary.,\...
# 4           4  \nOpen your project in Windows Movie Maker.\n,...
#
#                                                title  \
# 0                    How to Negotiate Mortgage Terms
# 1  How to Keep Your Knowledge of Technology Up to...
# 2               How to Use the in Game Map in Skyrim
# 3                    How to Treat a Broken Pinky Toe
# 4  How to Add Text to a Movie in Windows Movie Maker
#
#                                                 text  text_length  \
# 0   You should stop into several banks or credit ...          976
# 1   A great start is getting to know how you can ...          570
# ...

# %%
def preprocess(text):
  preprocess_text = text.strip().replace("\n","")
  return len(preprocess_text.split())

# %%
model = Summarizer()
# Out:
# Downloading:   0%|          | 0.00/434 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
myText = df_1024['text'][:]
allText = []

for i, text in enumerate(myText):
  allText.append(text)

print(len(allText))
# Out:
# 17884

# %%
allSummaries = []

for i, text in enumerate(allText):
  if i < n + 1:
    train_length = preprocess(text)
    m = round(0.33 * train_length)
    summary = ''.join(model(text, max_length=m))
    allSummaries.append(summary)
    df_1024['train_length'][i] = train_length
    df_1024['summary'][i] = summary
    df_1024['summary_length'][i] = len(summary.split())
    if i % 100 == 0:
      df_1024.to_csv('gdrive/MyDrive/SNLP_Coursework/WikiHow_sample_in1024_results_BERT.csv')
    print('Processed', i, 'out of', len(allText) / 2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_1024.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0  \nShop around for the best rate.,\nRequest quo...
# 1           1  \nBecome familiar with your resources.,\nKnow ...
# 2           2  \nKnow local maps.,\nKnow the world map.,\nAcc...
# 3           3  \nRemove your shoes and socks, if necessary.,\...
# 4           4  \nOpen your project in Windows Movie Maker.\n,...
#
#                                                title  \
# 0                    How to Negotiate Mortgage Terms
# 1  How to Keep Your Knowledge of Technology Up to...
# 2               How to Use the in Game Map in Skyrim
# 3                    How to Treat a Broken Pinky Toe
# 4  How to Add Text to a Movie in Windows Movie Maker
#
#                                                 text  text_length  \
# 0   You should stop into several banks or credit ...          976
# 1   A great start is getting to know how you can ...          570
# ...
